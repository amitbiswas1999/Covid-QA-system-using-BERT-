# %% [markdown]
# **Installing and importing libraries**

# %%
import pandas as pd
import numpy as np
import pickle5 as pickle

# %% [markdown]
# **Accessing the course dataset**

# %%
# Accessing the research papers and data

with open('metadata_sample.pkl', 'rb') as f:
  df_metadata = pickle.load(f)
with open('json_pdf_sample.pkl', 'rb') as f:
  df_pdf = pickle.load(f)
with open('json_pmc_sample.pkl', 'rb') as f:
  df_pmc = pickle.load(f)

# %%
df_metadata.head()
# Out:
#         cord_uid                                       sha  \
# 600880  n441sprx  feedfe27a4eee49d8a1d09f50e8ecfe73057602a
# 721427  95libakm  c2ca01f12643a88e059e81619fb971fa61de3971
# 701284  bjl0bjg2  d0d1e05bb14f068d8323807ba042860887b7aa00
# 603427  7ch1yln4  fb8c3a315b4a345dafc7e59be000e21bf965dea8
# 771175  zegp4jq4  ed4c180c272b047c6db958508fb9a8edd40cb1cb
#
#                       source_x  \
# 600880       Medline; PMC; WHO
# 721427  Elsevier; Medline; PMC
# 701284            Medline; PMC
# 603427            Medline; PMC
# 771175  Elsevier; Medline; PMC
#
#                                                     title  \
# 600880  Experiences and effects of telerehabilitation ...
# 721427  SCOAT-Net: A novel network for segmenting COVI...
# 701284  A Comprehensive Review on Factors Influences B...
# 603427  Opposition to cannabis legalization on public ...
# 771175          An epigenetic signature to fight COVID-19
#
#                                  doi       pmcid   pubmed_id      license  \
# 600880       10.4102/sajp.v77i1.1528  PMC8252170  34230898.0        cc-by
# 721427  10.1016/j.patcog.2021.108109  PMC8189738  34127870.0        no-cc
# 701284           10.2147/ijn.s291956  PMC7898217  33628021.0     cc-by-nc
# 603427  10.1016/j.lanwpc.2021.100142  PMC8315435  34327442.0  cc-by-nc-nd
# 771175   10.1016/j.ebiom.2021.103385  PMC8116817  33993054.0        no-cc
#
#                                                  abstract publish_time  \
# 600880  BACKGROUND: The announcement of a national loc...   2021-06-30
# 721427  Automatic segmentation of lung opacification f...   2021-06-10
# 701284  Exosomes are nanoscale-sized membrane vesicles...   2021-02-17
# 603427                                                NaN   2021-04-13
# 771175                                                NaN   2021-05-13
#
#                                                   authors  \
# 600880  Ebrahim, Humairaa; Pillay-Jayaraman, Prithi; L...
# 721427  Zhao, Shixuan; Li, Zhidan; Chen, Yang; Zhao, W...
# 701284  Gurunathan, Sangiliyandi; Kang, Min-Hee; Kim, ...
# 603427                 Smyth, Bobby P; Christie, Grant IG
# 771175                                   Herbein, Georges
#
#                            journal  mag_id who_covidence_id arxiv_id  \
# 600880          S Afr J Physiother     NaN              NaN      NaN
# 721427            Pattern Recognit     NaN              NaN      NaN
# 701284          Int J Nanomedicine     NaN              NaN      NaN
# 603427  Lancet Reg Health West Pac     NaN              NaN      NaN
# 771175                EBioMedicine     NaN              NaN      NaN
#
#                                            pdf_json_files  \
# 600880  document_parses/pdf_json/feedfe27a4eee49d8a1d0...
# 721427  document_parses/pdf_json/c2ca01f12643a88e059e8...
# 701284  document_parses/pdf_json/d0d1e05bb14f068d83238...
# 603427  document_parses/pdf_json/fb8c3a315b4a345dafc7e...
# 771175  document_parses/pdf_json/ed4c180c272b047c6db95...
#
#                                       pmc_json_files  \
# 600880  document_parses/pmc_json/PMC8252170.xml.json
# 721427  document_parses/pmc_json/PMC8189738.xml.json
# 701284  document_parses/pmc_json/PMC7898217.xml.json
# 603427  document_parses/pmc_json/PMC8315435.xml.json
# 771175  document_parses/pmc_json/PMC8116817.xml.json
#
#                                                       url        s2_id
# 600880  https://www.ncbi.nlm.nih.gov/pubmed/34230898/;...  235720984.0
# 721427  https://www.ncbi.nlm.nih.gov/pubmed/34127870/;...  235382189.0
# 701284  https://doi.org/10.2147/ijn.s291956; https://w...  232016676.0
# 603427  https://doi.org/10.1016/j.lanwpc.2021.100142; ...  234824471.0
# 771175  https://www.ncbi.nlm.nih.gov/pubmed/33993054/;...  234487502.0

# %%
df_pdf.head(5)
# Out:
#                                     paper_id  \
# 1   302533d94d1eb66e7ea86c3f7e4f107720ee05e4
# 8   84391b305d5899e88f9a9a68460bf84a2e5bf733
# 17  4399ca131f6686e4fa66249de7aef7f4400335f1
# 33  3e077522c164ef58716b98b2a93e555f7e5ae1b6
# 37  7276b2a7819153f2a260b0e036416df363042e49
#
#                                              abstract  \
# 1
# 8   Background: The Aotearoa New Zealand populatio...
# 17  Background: Endometriosis is the presence of t...
# 33  Rabies is a highly fatal disease that is endem...
# 37  Background: There are few evidence-based non-p...
#
#                                             body_text
# 1   We are living in an era in which the world has...
# 8   Background "A hallmark of wellbeing for older ...
# 17  Trial registration: Australia and New Zealand ...
# 33  Rabies is a viral disease of mammals that is e...
# 37  (i.e., understanding, motivation, sense of ach...

# %%
df_pmc.head(5)
# Out:
#       paper_id                                          body_text
# 9   PMC7937399  Mycoplasma pneumoniae is one of the smallest s...
# 17  PMC8538230  The development of an effective vaccine agains...
# 28  PMC7798059  According to the United Nations World Tourism ...
# 33  PMC7168091  Hemophilia is a genetic disorder that is due t...
# 37  PMC8264283  In addition to nuclei, mitochondria are the on...

# %% [markdown]
# **Data Merging (merging the data from metadata, json pdf and json pmc files for research papers)**

# %%
#Merging the metadata and json pdf data
#sha column of metadata and paper_id of json_pdf data are same identifier for each record
df_merged = pd.merge(df_metadata,df_pdf,left_on='sha',right_on='paper_id',how='left').drop('paper_id',axis=1)

# %%
df_merged.head(2)
#abstract_x is the abstract from metadata and abstract_y is the abstract from json_pdf
# Out:
#    cord_uid                                       sha                source_x  \
# 0  n441sprx  feedfe27a4eee49d8a1d09f50e8ecfe73057602a       Medline; PMC; WHO
# 1  95libakm  c2ca01f12643a88e059e81619fb971fa61de3971  Elsevier; Medline; PMC
#
#                                                title  \
# 0  Experiences and effects of telerehabilitation ...
# 1  SCOAT-Net: A novel network for segmenting COVI...
#
#                             doi       pmcid   pubmed_id license  \
# 0       10.4102/sajp.v77i1.1528  PMC8252170  34230898.0   cc-by
# 1  10.1016/j.patcog.2021.108109  PMC8189738  34127870.0   no-cc
#
#                                           abstract_x publish_time  ...  \
# 0  BACKGROUND: The announcement of a national loc...   2021-06-30  ...
# 1  Automatic segmentation of lung opacification f...   2021-06-10  ...
#
#               journal mag_id  who_covidence_id arxiv_id  \
# 0  S Afr J Physiother    NaN               NaN      NaN
# 1    Pattern Recognit    NaN               NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/feedfe27a4eee49d8a1d0...
# 1  document_parses/pdf_json/c2ca01f12643a88e059e8...
#
#                                  pmc_json_files  \
# 0  document_parses/pmc_json/PMC8252170.xml.json
# 1  document_parses/pmc_json/PMC8189738.xml.json
#
#                                                  url        s2_id  \
# 0  https://www.ncbi.nlm.nih.gov/pubmed/34230898/;...  235720984.0
# 1  https://www.ncbi.nlm.nih.gov/pubmed/34127870/;...  235382189.0
#
#                                           abstract_y  \
# 0
# 1  • We propose a novel spatial-and channel-wise ...
#
#                                            body_text
# 0  On Thursday, 05 March 2020, the National Insti...
# 1  The coronavirus disease 2019 (COVID- 19) , whi...
#
# [2 rows x 21 columns]

# %%
#Lets merge the json_pmc data to the merged data too
df_merged = pd.merge(df_merged,df_pmc,left_on='pmcid',right_on='paper_id',how='left').drop('paper_id',axis=1)
df_merged.shape
# Out:
# (25000, 22)

# %% [markdown]
# **Data Cleaning and Preprocessing**

# %%
df_merged[df_merged.abstract_x != df_merged.abstract_y].shape
# Out:
# (22724, 22)

# %%
# check metadata abstract column to see if null values exist
df_merged.abstract_x.isnull().sum(),(df_merged.abstract_x == '').sum()
# Out:
# (3597, 0)

# %%
# Check pdf_json abstract to see if null values exist
df_merged.abstract_y.isnull().sum(),(df_merged.abstract_y == '').sum()
# Out:
# (1525, 6902)

# %% [markdown]
# Since the abstract_x from metadata is more reliable , we will use it but only fill by abstract_y text when abstract_x value is null

# %%
# Convert all columns to string and then replace abstract_y values
#df = df.astype(str)
df_merged["abstract_y"] = df_merged["abstract_y"].astype(str) 
df_merged['abstract_y'] = np.where(df_merged['abstract_y'].map(len) > 50, df_merged['abstract_y'], "na")

# %%
df_merged[df_merged['abstract_y'].apply(lambda x: len(str(x)) <= 10)]
# Out:
#        cord_uid                                                sha  \
# 0      n441sprx           feedfe27a4eee49d8a1d09f50e8ecfe73057602a
# 3      7ch1yln4           fb8c3a315b4a345dafc7e59be000e21bf965dea8
# 4      zegp4jq4           ed4c180c272b047c6db958508fb9a8edd40cb1cb
# 5      2rnllfz8           33703e2029e591656f0292aada7918ca734c4688
# 6      tmhpbof5           bd1a86a6c01513ed0b1cf8fc1590cf5962111f98
# ...         ...                                                ...
# 24986  d30hc3nb           00f864f7ee6d7aa005954da9c45f76515925e8f3
# 24987  pzlkvyjk           a99927909867bf30530558770197e81e8efe398c
# 24990  cflbdc15  3e014d18b10978b9509b5d52a28c2f61d048757b; b5ac...
# 24991  2qhogi3d           845d135afdcb1f2163f1279d8772177f593316e7
# 24993  72yq43sw           ec431d623308b5225fa327f5f51b25d7996a1be1
#
#                           source_x  \
# 0                Medline; PMC; WHO
# 3                     Medline; PMC
# 4           Elsevier; Medline; PMC
# 5                              PMC
# 6                              PMC
# ...                            ...
# 24986       Elsevier; Medline; PMC
# 24987                 Medline; PMC
# 24990  Elsevier; Medline; PMC; WHO
# 24991                          PMC
# 24993                 Medline; PMC
#
#                                                    title  \
# 0      Experiences and effects of telerehabilitation ...
# 3      Opposition to cannabis legalization on public ...
# 4              An epigenetic signature to fight COVID-19
# 5      Alpha-1 Antitrypsin as a Therapeutic Agent for...
# 6      Antibodies induced by receptor-binding domain ...
# ...                                                  ...
# 24986  Inactivated COVID-19 vaccines to make a global...
# 24987    SARS-CoV-2 in the kidney: bystander or culprit?
# 24990  SARS-CoV-2: Current trends in emerging variant...
# 24991               RCSEd launches app and brand refresh
# 24993  Depression and Anxiety Changes Among Sexual an...
#
#                                  doi       pmcid   pubmed_id      license  \
# 0            10.4102/sajp.v77i1.1528  PMC8252170  34230898.0        cc-by
# 3       10.1016/j.lanwpc.2021.100142  PMC8315435  34327442.0  cc-by-nc-nd
# 4        10.1016/j.ebiom.2021.103385  PMC8116817  33993054.0        no-cc
# 5        10.1007/978-3-319-23449-6_8  PMC7121596         NaN        no-cc
# 6         10.1016/j.jinf.2013.05.002  PMC7127489    23685240        no-cc
# ...                              ...         ...         ...          ...
# 24986  10.1016/s1473-3099(21)00020-7  PMC7906657  33548196.0        no-cc
# 24987     10.1038/s41581-020-00354-7  PMC7487445  32929200.0        no-cc
# 24990   10.1016/j.intimp.2021.108232  PMC8519814  34673335.0        no-cc
# 24991      10.1038/s41415-020-2394-9  PMC7662742    33188329        no-cc
# 24993     10.1007/s11606-020-05970-4  PMC7299558  32556877.0        cc-by
#
#                                               abstract_x publish_time  ...  \
# 0      BACKGROUND: The announcement of a national loc...   2021-06-30  ...
# 3                                                    NaN   2021-04-13  ...
# 4                                                    NaN   2021-05-13  ...
# 5      Alpha-1 antitrypsin is a positive acute phase ...   2015-07-23  ...
# 6                                                    NaN   2013-05-16  ...
# ...                                                  ...          ...  ...
# 24986                                                NaN   2021-02-03  ...
# 24987  A new study examined post-mortem kidney tissue...   2020-09-14  ...
# 24990  More than a year after the SARS-CoV-2 pandemic...   2021-10-16  ...
# 24991                                                NaN   2020-11-13  ...
# 24993                                                NaN   2020-06-17  ...
#
#       mag_id who_covidence_id  arxiv_id  \
# 0        NaN              NaN       NaN
# 3        NaN              NaN       NaN
# 4        NaN              NaN       NaN
# 5        NaN              NaN       NaN
# 6        NaN              NaN       NaN
# ...      ...              ...       ...
# 24986    NaN              NaN       NaN
# 24987    NaN              NaN       NaN
# 24990    NaN              NaN       NaN
# 24991    NaN              NaN       NaN
# 24993    NaN              NaN       NaN
#
#                                           pdf_json_files  \
# 0      document_parses/pdf_json/feedfe27a4eee49d8a1d0...
# 3      document_parses/pdf_json/fb8c3a315b4a345dafc7e...
# 4      document_parses/pdf_json/ed4c180c272b047c6db95...
# 5      document_parses/pdf_json/33703e2029e591656f029...
# 6      document_parses/pdf_json/bd1a86a6c01513ed0b1cf...
# ...                                                  ...
# 24986  document_parses/pdf_json/00f864f7ee6d7aa005954...
# 24987  document_parses/pdf_json/a99927909867bf3053055...
# 24990  document_parses/pdf_json/3e014d18b10978b9509b5...
# 24991  document_parses/pdf_json/845d135afdcb1f2163f12...
# 24993  document_parses/pdf_json/ec431d623308b5225fa32...
#
#                                      pmc_json_files  \
# 0      document_parses/pmc_json/PMC8252170.xml.json
# 3      document_parses/pmc_json/PMC8315435.xml.json
# 4      document_parses/pmc_json/PMC8116817.xml.json
# 5      document_parses/pmc_json/PMC7121596.xml.json
# 6      document_parses/pmc_json/PMC7127489.xml.json
# ...                                             ...
# 24986  document_parses/pmc_json/PMC7906657.xml.json
# 24987  document_parses/pmc_json/PMC7487445.xml.json
# 24990  document_parses/pmc_json/PMC8519814.xml.json
# 24991                                           NaN
# 24993  document_parses/pmc_json/PMC7299558.xml.json
#
#                                                      url        s2_id  \
# 0      https://www.ncbi.nlm.nih.gov/pubmed/34230898/;...  235720984.0
# 3      https://doi.org/10.1016/j.lanwpc.2021.100142; ...  234824471.0
# 4      https://www.ncbi.nlm.nih.gov/pubmed/33993054/;...  234487502.0
# 5      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 6      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# ...                                                  ...          ...
# 24986  https://www.ncbi.nlm.nih.gov/pubmed/33548196/;...  231866464.0
# 24987  https://www.ncbi.nlm.nih.gov/pubmed/32929200/;...  221643861.0
# 24990  https://api.elsevier.com/content/article/pii/S...  238992251.0
# 24991  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 24993  https://www.ncbi.nlm.nih.gov/pubmed/32556877/;...  219730961.0
#
#       abstract_y                                        body_text_x  \
# 0             na  On Thursday, 05 March 2020, the National Insti...
# 3             na  In their commentary on the decision of New Zea...
# 4             na  A novel coronavirus, SARS-CoV-2, emerged in Ch...
# 5             na  For many years, alpha-1 antitrypsin has been u...
# 6             na  Antibodies induced by receptorbinding domain i...
# ...          ...                                                ...
# 24986         na  Given that the risk of more severe COVID-19 in...
# 24987         na  Severe acute respiratory syndrome corona virus...
# 24990         na                                                NaN
# 24991         na  The BDA Northern Counties Branch AGM will be h...
# 24993         na  With SARS-COV-2 recently sweeping the globe, t...
#
#                                              body_text_y
# 0      As a result of the COVID-19 pandemic, many pat...
# 3      Both authors contributed to the drafting of th...
# 4      Research performed in our laboratories is supp...
# 5      For many years, alpha-1 antitrypsin has been u...
# 6                                 No reported conflicts.
# ...                                                  ...
# 24986  Many inactivated vaccines against severe acute...
# 24987  Refers to Braun, F. et al. SARS-CoV-2 renal tr...
# 24990  SARS-CoV-2 is the third member of the coronavi...
# 24991                                                NaN
# 24993  With SARS-COV-2 recently sweeping the globe, t...
#
# [8557 rows x 22 columns]

# %%
# replace abstract_x (metadata column) with abstract_y (pdf_json) value where abstract_x is null
df_merged.loc[df_merged.abstract_x.isnull() & (df_merged.abstract_y != 'na'),'abstract_x'] = df_merged[df_merged.abstract_x.isnull() & (df_merged.abstract_y != 'na')].abstract_y

# %%
# Do we have any remaining null abstract values. Not anymore. This is good.
# The null values have reduced which is what we had expected.
df_merged.abstract_x.isnull().sum()
# Out:
# 2951

# %%
# Lets get rid of the pdf_json abstract column and rename the metadata abstract column
df_merged.rename(columns = {'abstract_x' : 'abstract'}, inplace = True)
df_merged.drop('abstract_y',axis=1,inplace = True)
df_merged.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id', 'body_text_x', 'body_text_y'],
#       dtype='object')

# %%
# This is expected because body text comes from pdf and pmc folders
(df_merged.body_text_x != df_merged.body_text_y).sum()
# Out:
# 25000

# %%
df_merged.body_text_x.isnull().sum(),(df_merged.body_text_y == '').sum()
# Out:
# (1525, 0)

# %%
# This is expected because there are less papers in json_pmc
df_merged.body_text_y.isnull().sum()
# Out:
# 5393

# %%
# body_text_x is pdf_json. body_text_y comes from pmc_json
# Where available we use the text from pmc file trusting the statement quality
df_merged.body_text_x.isnull().sum(),(df_merged.body_text_y.isnull()).sum()
# Out:
# (1525, 5393)

# %%
# There are ~13k rows where body_text_x is null but body_text_y is not null
df_merged.loc[df_merged.body_text_x.isnull() & df_merged.body_text_y.notnull()]
# Out:
#        cord_uid                                                sha  \
# 40     j1sefamd  de4ddeb6cab0c5e13f3a6543ad5b7bb1215dc1da; 8e92...
# 76     x1mb8so9  309cc336df9d42f9189c9e5b2221e177bdacc89b; 9604...
# 83     v9xo446h  08a3e8af143f9b97a9ba5220f0de0fe0ae1bba06; 15d4...
# 86     39rck23u  480c6748788911bf7ca10d1214ef2e3f9b171b68; 7bf0...
# 109    ctzu3vdc  96bf39fec5a29ffe6b3b7c674c772220b3c2741e; 3df4...
# ...         ...                                                ...
# 24957  krs3e945  d5e11b2e05e7d6d625975a20b09ad40e94808330; 986b...
# 24958  et23099z  cb9ca2060dcc783d03a7fdfbba26ca5af8e01c08; 9b0b...
# 24963  mp1h8qei  1fbe66f9999da8542c19c9772b914934572820a7; 6958...
# 24972  c3sn7is3  ba28cdb04f3ce68934f9e6de894e478dfbb008c1; 203d...
# 24990  cflbdc15  3e014d18b10978b9509b5d52a28c2f61d048757b; b5ac...
#
#                                  source_x  \
# 40                           Medline; PMC
# 76                           Medline; PMC
# 83                 Elsevier; Medline; PMC
# 86                           Medline; PMC
# 109           Elsevier; Medline; PMC; WHO
# ...                                   ...
# 24957                                 PMC
# 24958              Elsevier; Medline; PMC
# 24963                        Medline; PMC
# 24972  ArXiv; Elsevier; Medline; PMC; WHO
# 24990         Elsevier; Medline; PMC; WHO
#
#                                                    title  \
# 40     The effect of eviction moratoria on the transm...
# 76     Early Transmission Dynamics, Spread, and Genom...
# 83        Regulation of stress granules in virus systems
# 86     Study protocol for a randomised controlled fea...
# 109    Telaprevir is a potential drug for repurposing...
# ...                                                  ...
# 24957  Fast estimation of time-varying infectious dis...
# 24958  Multi-tier cloud infrastructure support for re...
# 24963  Multi-peaked adaptive landscape for chikunguny...
# 24972  A stochastic model for the influence of social...
# 24990  SARS-CoV-2: Current trends in emerging variant...
#
#                                  doi       pmcid   pubmed_id   license  \
# 40        10.1038/s41467-021-22521-5  PMC8050248  33859196.0     cc-by
# 76            10.3201/eid2702.203767  PMC7853578  33496228.0     no-cc
# 83         10.1016/j.tim.2012.02.001  PMC3322245  22405519.0  green-oa
# 86       10.1136/bmjopen-2020-041626  PMC7783524  33397667.0  cc-by-nc
# 109    10.1016/j.heliyon.2021.e07962  PMC8426143  34518806.0     no-cc
# ...                              ...         ...         ...       ...
# 24957   10.1371/journal.pcbi.1008124  PMC7549798    32956345     cc-by
# 24958   10.1016/j.simpat.2016.06.005  PMC7270859  32518536.0     no-cc
# 24963             10.1038/ncomms5084  PMC7091890  24933611.0     no-cc
# 24972    10.1016/j.physa.2021.126367  PMC8502768  34658496.0     no-cc
# 24990   10.1016/j.intimp.2021.108232  PMC8519814  34673335.0     no-cc
#
#                                                 abstract publish_time  ...  \
# 40     Massive unemployment during the COVID-19 pande...   2021-04-15  ...
# 76     We report an epidemiologic analysis of 4,210 c...   2021-02-19  ...
# 83     Virus infection initiates a number of cellular...   2012-04-01  ...
# 86     INTRODUCTION: Patient adherence to adjuvant en...   2021-01-04  ...
# 109    Drug repurposing is an important approach to t...   2021-09-09  ...
# ...                                                  ...          ...  ...
# 24957  Compartmental epidemic models have been used e...   2020-09-21  ...
# 24958  The exceptional outbreaks of a number of epide...   2016-07-01  ...
# 24963  Host species-specific fitness landscapes large...   2014-06-16  ...
# 24972  The short-term economic consequences of the cr...   2021-12-15  ...
# 24990  More than a year after the SARS-CoV-2 pandemic...   2021-10-16  ...
#
#                         journal mag_id  who_covidence_id    arxiv_id  \
# 40                   Nat Commun    NaN               NaN         NaN
# 76             Emerg Infect Dis    NaN               NaN         NaN
# 83       Trends in Microbiology    NaN               NaN         NaN
# 86                     BMJ Open    NaN               NaN         NaN
# 109                     Heliyon    NaN               NaN         NaN
# ...                         ...    ...               ...         ...
# 24957          PLoS Comput Biol    NaN               NaN         NaN
# 24958  Simul Model Pract Theory    NaN               NaN         NaN
# 24963                Nat Commun    NaN               NaN         NaN
# 24972                 Physica A    NaN               NaN  2103.15577
# 24990       Int Immunopharmacol    NaN               NaN         NaN
#
#                                           pdf_json_files  \
# 40     document_parses/pdf_json/de4ddeb6cab0c5e13f3a6...
# 76     document_parses/pdf_json/309cc336df9d42f9189c9...
# 83     document_parses/pdf_json/08a3e8af143f9b97a9ba5...
# 86     document_parses/pdf_json/480c6748788911bf7ca10...
# 109    document_parses/pdf_json/96bf39fec5a29ffe6b3b7...
# ...                                                  ...
# 24957  document_parses/pdf_json/d5e11b2e05e7d6d625975...
# 24958  document_parses/pdf_json/cb9ca2060dcc783d03a7f...
# 24963  document_parses/pdf_json/1fbe66f9999da8542c19c...
# 24972  document_parses/pdf_json/ba28cdb04f3ce68934f9e...
# 24990  document_parses/pdf_json/3e014d18b10978b9509b5...
#
#                                      pmc_json_files  \
# 40     document_parses/pmc_json/PMC8050248.xml.json
# 76     document_parses/pmc_json/PMC7853578.xml.json
# 83     document_parses/pmc_json/PMC3322245.xml.json
# 86     document_parses/pmc_json/PMC7783524.xml.json
# 109    document_parses/pmc_json/PMC8426143.xml.json
# ...                                             ...
# 24957  document_parses/pmc_json/PMC7549798.xml.json
# 24958  document_parses/pmc_json/PMC7270859.xml.json
# 24963  document_parses/pmc_json/PMC7091890.xml.json
# 24972  document_parses/pmc_json/PMC8502768.xml.json
# 24990  document_parses/pmc_json/PMC8519814.xml.json
#
#                                                      url        s2_id  \
# 40     https://www.ncbi.nlm.nih.gov/pubmed/33859196/;...  233257667.0
# 76     https://doi.org/10.3201/eid2702.203767; https:...  231711065.0
# 83     https://doi.org/10.1016/j.tim.2012.02.001; htt...   46260378.0
# 86     https://doi.org/10.1136/bmjopen-2020-041626; h...  230508161.0
# 109    https://api.elsevier.com/content/article/pii/S...  237444052.0
# ...                                                  ...          ...
# 24957  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 24958  https://doi.org/10.1016/j.simpat.2016.06.005; ...  205175747.0
# 24963  https://www.ncbi.nlm.nih.gov/pubmed/24933611/;...    1489955.0
# 24972  https://arxiv.org/pdf/2103.15577v1.pdf; https:...  232404306.0
# 24990  https://api.elsevier.com/content/article/pii/S...  238992251.0
#
#        body_text_x                                        body_text_y
# 40             NaN  The COVID-19 epidemic has caused unprecedented...
# 76             NaN  To perform molecular detection of SARS-CoV-2, ...
# 83             NaN  Eukaryotic cells can contain multiple types of...
# 86             NaN  Up to 75% of female patients diagnosed with ea...
# 109            NaN  The coronavirus disease 2019 (COVID-19) pandem...
# ...            ...                                                ...
# 24957          NaN  The transmission rate of an infectious disease...
# 24958          NaN  With the frequent spreading and outbreaks of i...
# 24963          NaN  A critical factor determining a pathogen’s pot...
# 24972          NaN  Even before the Covid-19 pandemic, the World H...
# 24990          NaN  SARS-CoV-2 is the third member of the coronavi...
#
# [1437 rows x 21 columns]

# %%
# We are trusting the text from pmc folder to be of higher quality as it contains full text. 
# Hence we will replace with body_text_x with body_text_y where body_text_y exists
df_merged.loc[df_merged.body_text_y.notnull(),'body_text_x'] = df_merged.loc[df_merged.body_text_y.notnull(), 'body_text_y']

# %%
# Lets get rid of the pdf_pmc body text column and rename the body text column
df_merged.rename(columns = {'body_text_x' : 'body_text'}, inplace = True)
df_merged.drop('body_text_y',axis=1,inplace = True)
df_merged.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id', 'body_text'],
#       dtype='object')

# %%
# Body text null values have now decreased.
df_merged.body_text.isnull().sum()
# Out:
# 88

# %%
df_merged.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id', 'body_text'],
#       dtype='object')

# %%
df_final = df_merged[['sha', 'title', 'abstract', 'publish_time', 'authors', 'url', 'body_text']]

# %%
df_final.head()
# Out:
#                                         sha  \
# 0  feedfe27a4eee49d8a1d09f50e8ecfe73057602a
# 1  c2ca01f12643a88e059e81619fb971fa61de3971
# 2  d0d1e05bb14f068d8323807ba042860887b7aa00
# 3  fb8c3a315b4a345dafc7e59be000e21bf965dea8
# 4  ed4c180c272b047c6db958508fb9a8edd40cb1cb
#
#                                                title  \
# 0  Experiences and effects of telerehabilitation ...
# 1  SCOAT-Net: A novel network for segmenting COVI...
# 2  A Comprehensive Review on Factors Influences B...
# 3  Opposition to cannabis legalization on public ...
# 4          An epigenetic signature to fight COVID-19
#
#                                             abstract publish_time  \
# 0  BACKGROUND: The announcement of a national loc...   2021-06-30
# 1  Automatic segmentation of lung opacification f...   2021-06-10
# 2  Exosomes are nanoscale-sized membrane vesicles...   2021-02-17
# 3                                                NaN   2021-04-13
# 4                                                NaN   2021-05-13
#
#                                              authors  \
# 0  Ebrahim, Humairaa; Pillay-Jayaraman, Prithi; L...
# 1  Zhao, Shixuan; Li, Zhidan; Chen, Yang; Zhao, W...
# 2  Gurunathan, Sangiliyandi; Kang, Min-Hee; Kim, ...
# 3                 Smyth, Bobby P; Christie, Grant IG
# 4                                   Herbein, Georges
#
#                                                  url  \
# 0  https://www.ncbi.nlm.nih.gov/pubmed/34230898/;...
# 1  https://www.ncbi.nlm.nih.gov/pubmed/34127870/;...
# 2  https://doi.org/10.2147/ijn.s291956; https://w...
# 3  https://doi.org/10.1016/j.lanwpc.2021.100142; ...
# 4  https://www.ncbi.nlm.nih.gov/pubmed/33993054/;...
#
#                                            body_text
# 0  As a result of the COVID-19 pandemic, many pat...
# 1  The coronavirus disease 2019 (COVID-19), which...
# 2  Extracellular vesicles (EVs) including exosome...
# 3  Both authors contributed to the drafting of th...
# 4  Research performed in our laboratories is supp...

# %%
df_final = df_final.dropna(axis=0,subset=['body_text', 'title'])
df_final.isnull().sum()
# Out:
# sha                0
# title              0
# abstract        2940
# publish_time       0
# authors          227
# url                0
# body_text          0
# dtype: int64

# %%
df_final.shape
# Out:
# (24910, 7)

# %%
df_final.to_csv('FINAL_CORD_DATA.csv', index=False)
